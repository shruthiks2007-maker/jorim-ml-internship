# %%
import pandas as pd

df = pd.read_csv("Housing.csv")

# %%
print(df["mainroad"].unique())
# Out:
# ['yes' 'no']

# %%
# Encode Yes/No columns

df["mainroad"] = df["mainroad"].map({"yes": 1, "no": 0})

df["guestroom"] = df["guestroom"].map({"yes": 1, "no": 0})

df["basement"] = df["basement"].map({"yes": 1, "no": 0})

df["hotwaterheating"] = df["hotwaterheating"].map({"yes": 1, "no": 0})

df["airconditioning"] = df["airconditioning"].map({"yes": 1, "no": 0})

df["prefarea"] = df["prefarea"].map({"yes": 1, "no": 0})


# Encode furnishingstatus

df["furnishingstatus"] = df["furnishingstatus"].map({
    "unfurnished": 0,
    "semi-furnished": 1,
    "furnished": 2
})

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0  13300000  7420         4          2        3         1          0
# 1  12250000  8960         4          4        4         1          0
# 2  12250000  9960         3          2        2         1          0
# 3  12215000  7500         4          2        2         1          0
# 4  11410000  7420         4          1        2         1          1
#
#    basement  hotwaterheating  airconditioning  parking  prefarea  \
# 0         0                0                1        2         1
# 1         0                0                1        3         0
# 2         1                0                0        2         1
# 3         1                0                1        3         1
# 4         1                0                1        2         0
#
#    furnishingstatus
# 0                 2
# 1                 2
# 2                 1
# 3                 2
# 4                 2

# %%
x = df.drop("price",axis=1)
y = df["price"]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train,y_train)
y_pred = model.predict(x_test)

# %%
print(y_pred)
# Out:
# [5203691.70963178 7257004.02115475 3062828.59668171 4559591.65374424
#  3332932.30559782 3563080.67918997 5645466.31219972 6413979.66873635
#  2755831.54819    2668938.66075228 9570600.29915353 2827431.50860062
#  3195686.2583409  3352263.99438471 3713879.49996131 5301088.24435749
#  2987920.2666968  4810799.8212371  4383031.70489929 3525092.18938646
#  5796259.50068013 5840000.70299301 2760214.608641   4762590.14920608
#  5204755.73895206 7515542.71619024 3254681.68956382 5236164.45964444
#  8178523.16820284 3434166.15675649 6443921.58767581 3346004.77919184
#  6742324.74004133 4154936.84088665 3589152.47491253 5788125.92515322
#  4768370.18154076 4391684.04193171 3217657.04549935 4638196.61928878
#  4522160.27786714 3541284.06127245 7238136.1194117  4021515.68926614
#  3701978.76822757 4298879.55563098 6705004.0206061  3993466.52296896
#  3798185.05328059 3451821.5624289  7293996.86867461 2832905.26972678
#  4378698.1476993  4468002.85418353 3714623.89765883 2718466.90282779
#  7524449.64983626 2950437.1495281  4194596.28592921 2795827.773181
#  4801788.72577028 3618230.29875972 5091685.77019752 4248122.70647651
#  4729964.20281946 4620982.9363411  7215846.76983926 3485106.19132682
#  5933820.14349914 6236580.98095547 4809923.61015999 5130920.22938947
#  4527282.87392583 8006869.07208366 3543927.63713715 5463086.05281816
#  3902441.28505163 4661063.63495886 4825370.89331733 4276803.47099967
#  7754072.71344458 4008573.23235629 6500977.91345037 5386796.00909808
#  2785343.0092764  6836356.36771845 2638553.49378047 3634231.99215348
#  8004072.41154001 8048399.75418243 3227573.69687308 5935167.4198354
#  3605772.48317454 3817767.91420862 7631673.34074558 4775106.62670537
#  5093491.44442931 6447437.14797692 4943449.6813564  5943929.14295426
#  3810460.26405425 6457426.32302761 3701491.23218178 5960492.47343073
#  4933137.14530295 4377133.13624287 7009335.02696999 6351460.97128317
#  6409340.41089671]

# %%
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(y_test,y_pred)
print(mae)
# Out:
# 979679.6912959901

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y_test,y_pred)
print(r2)
# Out:
# 0.6494754192267803
