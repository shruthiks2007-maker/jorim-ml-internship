# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("titanic.csv")
df.head()
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
median_age = df["Age"].median()
print(median_age)
# Out:
# 28.0

# %%
df["Age"] = df["Age"].fillna(median_age)
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
x = df[["Pclass","Age","Fare"]]
y = df["Survived"]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(n_estimators=100,random_state=42)
model.fit(x_train,y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
train_pred = model.predict(x_train)

# %%
from sklearn.metrics import accuracy_score
accuracy_calculate = accuracy_score(y_train,train_pred)
print(accuracy_calculate)
# Out:
# 0.952247191011236

# %%
test_pred = model.predict(x_test)
from sklearn.metrics import accuracy_score
accuracy_test = accuracy_score(y_test,test_pred)
print(accuracy_test)
# Out:
# 0.7262569832402235

# %%
from sklearn.metrics import accuracy_score
accuracy_test = accuracy_score(y_test,test_pred)
print(accuracy_test)
# Out:
# 0.7262569832402235

# %%
importance = model.feature_importances_

for feature, score in zip(x.columns, importance):
    print(feature, ":", score)
# Out:
# Pclass : 0.09144449715873891
# Age : 0.4044619396598389
# Fare : 0.5040935631814222

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix = confusion_matrix(y_test,test_pred)
print(confusion_matrix)
# Out:
# [[87 18]
#  [31 43]]

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.83      0.78       105
#            1       0.70      0.58      0.64        74
#
#     accuracy                           0.73       179
#    macro avg       0.72      0.70      0.71       179
# weighted avg       0.72      0.73      0.72       179
